# %% [markdown]
# # Data Frame Merge

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Append
# Combining Series and Dataframes by Row

# %%
train_data = pd.read_csv("C:/Users/LENOVO/Python/california_housing_train.csv")

# %%
test_data = pd.read_csv("C:/Users/LENOVO/Python/california_housing_test.csv")

# %%
train_data.shape
# Out:
# (17000, 9)

# %%
train_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
test_data.shape
# Out:
# (3000, 9)

# %%
test_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
full_data = train_data.append(test_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2980\3575416878.py in ?()
# ----> 1 full_data = train_data.append(test_data)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
full_data = pd.concat([train_data, test_data], ignore_index=True)

# %%
full_data.shape
# Out:
# (20000, 9)

# %%
full_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# ## Concatenate

# %%
data1 = {"country" : ["JPY", "CHN", "IND"],
         "year" : [2019, 2019, 2020]}

data2 = {"country" : ["JPY", "CHN", "KOR"],
         "city" : ["Tokyo", "Beijing", "Seoul"]}

# %%
data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)

# %%
print(data1)
print(data2)
# Out:
#   country  year
# 0     JPY  2019
# 1     CHN  2019
# 2     IND  2020
#   country     city
# 0     JPY    Tokyo
# 1     CHN  Beijing
# 2     KOR    Seoul

# %%
df_column = pd.concat([data1, data2], axis = 1)
df_column
# Out:
#   country  year country     city
# 0     JPY  2019     JPY    Tokyo
# 1     CHN  2019     CHN  Beijing
# 2     IND  2020     KOR    Seoul

# %%
df_row = pd.concat([data1, data2], axis = 0)
df_row
# Out:
#   country    year     city
# 0     JPY  2019.0      NaN
# 1     CHN  2019.0      NaN
# 2     IND  2020.0      NaN
# 0     JPY     NaN    Tokyo
# 1     CHN     NaN  Beijing
# 2     KOR     NaN    Seoul

# %% [markdown]
# ## Join

# %%
population = pd.read_csv("C:/Users/LENOVO/Python/worldbank_pope.csv")
population.head()
# Out:
#   Country Name Country Code  Year      Value
# 0  Afghanistan          AFG  1960  9035043.0
# 1  Afghanistan          AFG  1961  9214083.0
# 2  Afghanistan          AFG  1962  9404406.0
# 3  Afghanistan          AFG  1963  9604487.0
# 4  Afghanistan          AFG  1964  9814318.0

# %%
gdp = pd.read_csv("C:/Users/LENOVO/Python/worldbank_gdpe.csv")
gdp.head()
# Out:
#   Country Name Country Code  Year         Value
# 0  Afghanistan          AFG  2000  3.521418e+09
# 1  Afghanistan          AFG  2001  2.813572e+09
# 2  Afghanistan          AFG  2002  3.825701e+09
# 3  Afghanistan          AFG  2003  4.520947e+09
# 4  Afghanistan          AFG  2004  5.224897e+09

# %% [markdown]
# ### Outer join

# %%
world_bank_outer = population.merge(gdp,
                                    on = ["Country Code", "Country Name", "Year"],
                                    how = "outer")

# %%
world_bank_outer
# Out:
#       Country Name Country Code  Year     Value_x       Value_y
# 0            Aruba          ABW  1960     54922.0           NaN
# 1            Aruba          ABW  1961     55578.0           NaN
# 2            Aruba          ABW  1962     56320.0           NaN
# 3            Aruba          ABW  1963     57002.0           NaN
# 4            Aruba          ABW  1964     57619.0           NaN
# ...            ...          ...   ...         ...           ...
# 16925     Zimbabwe          ZWE  2019  15271368.0  2.183223e+10
# 16926     Zimbabwe          ZWE  2020  15526888.0  2.150970e+10
# 16927     Zimbabwe          ZWE  2021  15797210.0  2.837124e+10
# 16928     Zimbabwe          ZWE  2022  16069056.0  2.736663e+10
# 16929     Zimbabwe          ZWE  2023  16340822.0  2.653827e+10
#
# [16930 rows x 5 columns]

# %% [markdown]
# ### Inner join

# %%
world_bank_inner = population.merge(gdp,
                                    on = ["Country Code", "Country Name", "Year"],
                                    how = "inner")
world_bank_inner
# Out:
#       Country Name Country Code  Year     Value_x       Value_y
# 0      Afghanistan          AFG  2000  20130327.0  3.521418e+09
# 1      Afghanistan          AFG  2001  20284307.0  2.813572e+09
# 2      Afghanistan          AFG  2002  21378117.0  3.825701e+09
# 3      Afghanistan          AFG  2003  22733049.0  4.520947e+09
# 4      Afghanistan          AFG  2004  23560654.0  5.224897e+09
# ...            ...          ...   ...         ...           ...
# 13974     Zimbabwe          ZWE  2019  15271368.0  2.183223e+10
# 13975     Zimbabwe          ZWE  2020  15526888.0  2.150970e+10
# 13976     Zimbabwe          ZWE  2021  15797210.0  2.837124e+10
# 13977     Zimbabwe          ZWE  2022  16069056.0  2.736663e+10
# 13978     Zimbabwe          ZWE  2023  16340822.0  2.653827e+10
#
# [13979 rows x 5 columns]

# %% [markdown]
# ### Left join

# %%
world_bank_left = population.merge(gdp,
                                    on = ["Country Code", "Country Name", "Year"],
                                    how = "left")
world_bank_left
# Out:
#       Country Name Country Code  Year     Value_x       Value_y
# 0      Afghanistan          AFG  1960   9035043.0           NaN
# 1      Afghanistan          AFG  1961   9214083.0           NaN
# 2      Afghanistan          AFG  1962   9404406.0           NaN
# 3      Afghanistan          AFG  1963   9604487.0           NaN
# 4      Afghanistan          AFG  1964   9814318.0           NaN
# ...            ...          ...   ...         ...           ...
# 16925     Zimbabwe          ZWE  2019  15271368.0  2.183223e+10
# 16926     Zimbabwe          ZWE  2020  15526888.0  2.150970e+10
# 16927     Zimbabwe          ZWE  2021  15797210.0  2.837124e+10
# 16928     Zimbabwe          ZWE  2022  16069056.0  2.736663e+10
# 16929     Zimbabwe          ZWE  2023  16340822.0  2.653827e+10
#
# [16930 rows x 5 columns]

# %% [markdown]
# ### Right Join

# %%
world_bank_right = population.merge(gdp,
                                    on = ["Country Code", "Country Name", "Year"],
                                    how = "right")
world_bank_right
# Out:
#       Country Name Country Code  Year     Value_x       Value_y
# 0      Afghanistan          AFG  2000  20130327.0  3.521418e+09
# 1      Afghanistan          AFG  2001  20284307.0  2.813572e+09
# 2      Afghanistan          AFG  2002  21378117.0  3.825701e+09
# 3      Afghanistan          AFG  2003  22733049.0  4.520947e+09
# 4      Afghanistan          AFG  2004  23560654.0  5.224897e+09
# ...            ...          ...   ...         ...           ...
# 13974     Zimbabwe          ZWE  2019  15271368.0  2.183223e+10
# 13975     Zimbabwe          ZWE  2020  15526888.0  2.150970e+10
# 13976     Zimbabwe          ZWE  2021  15797210.0  2.837124e+10
# 13977     Zimbabwe          ZWE  2022  16069056.0  2.736663e+10
# 13978     Zimbabwe          ZWE  2023  16340822.0  2.653827e+10
#
# [13979 rows x 5 columns]

# %% [markdown]
# ### Multiple

# %%
world_bank_multiple = population.merge(gdp,
                                    on = ["Country Code", "Country Code", "Year"]
                                    )
world_bank_multiple
# Out:
#       Country Name_x Country Code  Year     Value_x Country Name_y  \
# 0        Afghanistan          AFG  2000  20130327.0    Afghanistan
# 1        Afghanistan          AFG  2001  20284307.0    Afghanistan
# 2        Afghanistan          AFG  2002  21378117.0    Afghanistan
# 3        Afghanistan          AFG  2003  22733049.0    Afghanistan
# 4        Afghanistan          AFG  2004  23560654.0    Afghanistan
# ...              ...          ...   ...         ...            ...
# 13974       Zimbabwe          ZWE  2019  15271368.0       Zimbabwe
# 13975       Zimbabwe          ZWE  2020  15526888.0       Zimbabwe
# 13976       Zimbabwe          ZWE  2021  15797210.0       Zimbabwe
# 13977       Zimbabwe          ZWE  2022  16069056.0       Zimbabwe
# 13978       Zimbabwe          ZWE  2023  16340822.0       Zimbabwe
#
#             Value_y
# 0      3.521418e+09
# 1      2.813572e+09
# 2      3.825701e+09
# 3      4.520947e+09
# 4      5.224897e+09
# ...             ...
# 13974  2.183223e+10
# 13975  2.150970e+10
# 13976  2.837124e+10
# 13977  2.736663e+10
# 13978  2.653827e+10
#
# [13979 rows x 6 columns]

# %%
population
# Out:
#       Country Name Country Code  Year       Value
# 0      Afghanistan          AFG  1960   9035043.0
# 1      Afghanistan          AFG  1961   9214083.0
# 2      Afghanistan          AFG  1962   9404406.0
# 3      Afghanistan          AFG  1963   9604487.0
# 4      Afghanistan          AFG  1964   9814318.0
# ...            ...          ...   ...         ...
# 16925     Zimbabwe          ZWE  2019  15271368.0
# 16926     Zimbabwe          ZWE  2020  15526888.0
# 16927     Zimbabwe          ZWE  2021  15797210.0
# 16928     Zimbabwe          ZWE  2022  16069056.0
# 16929     Zimbabwe          ZWE  2023  16340822.0
#
# [16930 rows x 4 columns]
