# %% [markdown]
# # Matplotlib

# %% [markdown]
# # pyplot

# %% [markdown]
# example 1

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 10]

plt.plot(x, y)

plt.show()

# %% [markdown]
# ## Menambahkan title

# %% [markdown]
# __syntax:__
#
# __matplotlib.pyplot.title(label, fontdict=None, loc=’center’, pad=None, **kwargs)__

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

plt.plot(x, y)

plt.title("grafik linear")

plt.show()

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

plt.plot(x, y)

plt.title("grafik linear", fontsize=20, color="navy")

plt.show()

# %% [markdown]
# # Menambahkan label sumbu x dan sumbu y

# %% [markdown]
# Dalam istilah awam, label X dan label Y adalah sebutan yang diberikan masing-masing untuk sumbu X dan sumbu Y. Ini dapat ditambahkan ke grafik dengan menggunakan metode xlabel() dan ylabel().

# %% [markdown]
# __syntax:__
#
# __matplotlib.pyplot.xlabel(xlabel, fontdict=None, labelpad=None, **kwargs)__
#
# __matplotlib.pyplot.ylabel(ylabel, fontdict=None, labelpad=None, **kwargs)__

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

plt.plot(x, y)

plt.title("Grafik Linear", fontsize=15, color="blue")

plt.ylabel('Sumbu Y')

plt.xlabel('Sumbu X')

plt.show()

# %% [markdown]
# ## Menetapkan Batas dan label Centang

# %% [markdown]
# Kita mungkin telah melihat bahwa Matplotlib secara otomatis menetapkan nilai dan penanda (titik) dari sumbu X dan Y, namun, dimungkinkan untuk mengatur batas dan penanda secara manual. Fungsi xlim() dan ylim() digunakan untuk mengatur batas sumbu X dan sumbu Y masing-masing. Demikian pula, fungsi xticks() dan yticks() digunakan untuk menyetel label centang.

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

plt.plot(x, y)

plt.title("Grafik Linear", fontsize=17, color="blue")

plt.ylabel('Sumbu Y')

plt.xlabel('Sumbu X')

plt.ylim(0, 80)

plt.xticks(x, labels=["one", "two", "three", "four"])

plt.show()

# %% [markdown]
# ## Menambahkan legends

# %% [markdown]
# Legend adalah area yang menggambarkan elemen grafik. Secara sederhana, ini mencerminkan data yang ditampilkan dalam sumbu Y. Biasanya muncul sebagai kotak yang berisi sampel kecil dari setiap warna pada grafik dan deskripsi kecil tentang arti data ini.
#
# Atribut bbox_to_anchor=(x, y) dari fungsi legend() digunakan untuk menentukan koordinat legend, dan atribut ncol mewakili jumlah kolom yang dimiliki legend. Nilai defaultnya adalah 1.

# %% [markdown]
# __syntax:__
#
# __matplotlib.pyplot.legend([“name1”, “name2”], bbox_to_anchor=(x, y), ncol=1)__

# %%
import matplotlib.pyplot as plt


x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

plt.plot(x, y)

plt.title("Grafik Linear", fontsize=18, color="blue")

plt.ylabel('Sumbu Y')

plt.xlabel('Sumbu X')

plt.ylim(0, 80)

plt.xticks(x, labels=["satu", "dua", "tiga", "empat"])

plt.legend(["GFG"])

plt.show()

# %% [markdown]
# ## Figure Class

# %% [markdown]
# class matplotlib.figure.Figure(figsize=None, dpi=None, facecolor=None, edgecolor=None, linewidth=0.0, frameon=None, subplotpars=None, tight_layout=None, constrained_layout=None)

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# Membuat figur baru dengan lebar = 7 inci dan tinggi = 5 inci dengan warna wajah grey, warna tepi merah, dan lebar garis
# tepi 7 inci
fig = plt.figure(figsize =(7, 5), facecolor='grey',
				edgecolor='b', linewidth=7)

# Membuat sumbu baru untuk gambar
ax = fig.add_axes([1, 1, 1, 1])

# Menambahkan data yang akan diplot
ax.plot(x, y)

# Menambahkan judul pada plot
plt.title("Grafik Linear", fontsize=25, color="yellow")

# Menambahkan label pada sumbu y
plt.ylabel('Sumbu Y')

# Menambahkan label pada sumbu x
plt.xlabel('Sumbu X')

# Menetapkan limit sumbu y
plt.ylim(0, 80)

# Menetapkan label sumbu x
plt.xticks(x, labels=["satu", "dua", "tiga", "empat"])

# Menambahkan legenda
plt.legend(["GFG"])

plt.show()

# %% [markdown]
# ## Axes Class

# %% [markdown]
# class Axes adalah unit paling dasar dan fleksibel untuk membuat sub-plot. Gambar tertentu mungkin berisi banyak sumbu, tetapi sumbu tertentu hanya dapat ada dalam satu gambar. Fungsi axes() membuat objek axes.

# %% [markdown]
# __syntax:__
#
# __axes([left, bottom, width, height])__

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure


x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

fig = plt.figure(figsize = (5, 4))

ax = fig.add_axes([1, 1, 1, 1])

ax1 = ax.plot(x, y)

ax2 = ax.plot(y, x)

ax.set_title("Grafik Linear")

ax.set_xlabel("Sumbu X")
ax.set_ylabel("Sumbu Y")

ax.legend(labels = ('garis 1', 'garis 2'))

plt.show()

# %% [markdown]
# ## Multiple Plot (Plot lebih dari 1)

# %% [markdown]
# Kita telah mempelajari tentang komponen dasar graf yang dapat ditambahkan sehingga dapat menyampaikan informasi lebih lanjut. Salah satu caranya adalah dengan memanggil fungsi plot berulang kali dengan kumpulan nilai yang berbeda seperti yang ditunjukkan pada contoh di atas. Sekarang mari kita lihat cara memplot banyak grafik menggunakan beberapa fungsi dan juga cara memplot subplot.

# %% [markdown]
# contoh 1 menggunakan __add_axes()__

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

fig = plt.figure(figsize =(5, 4))

ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

ax2 = fig.add_axes([1, 0.1, 0.8, 0.8])

ax1.plot(x, y)
ax2.plot(y, x)

plt.show()

# %% [markdown]
# contoh 2

# %% [markdown]
# __syntax:__
#
# __subplot(nrows, ncols, index, **kwargs)__
#
# __subplot(pos, **kwargs)__
#
# __subplot(ax)__

# %%
import matplotlib.pyplot as plt


x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

plt.figure()

plt.subplot(121)
plt.plot(x, y)

plt.subplot(122)
plt.plot(y, x)

# %% [markdown]
# contoh 3

# %% [markdown]
# __syntax:__
#
# __matplotlib.pyplot.subplots(nrows=1, ncols=1, sharex=False, sharey=False, squeeze=True, subplot_kw=None, gridspec_kw=None, **fig_kw)__

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

fig, axes = plt.subplots(1, 2)

axes[0].plot(x, y)

axes[0].plot(y, x)

axes[1].plot(x, y)

# %% [markdown]
# contoh 4

# %% [markdown]
# Menggunakan __subplot2grid()__

# %% [markdown]
# Fungsi ini membuat objek sumbu di lokasi tertentu di dalam kisi dan juga membantu merentangkan objek sumbu di beberapa baris atau kolom. Dengan kata yang lebih sederhana, fungsi ini digunakan untuk membuat beberapa grafik dalam gambar yang sama.

# %% [markdown]
# __syntax :__ \
# __Plt.subplot2grid(shape, location, rowspan, colspan)__

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

axes1 = plt.subplot2grid (
(7, 1), (0, 0), rowspan = 2, colspan = 1)

axes2 = plt.subplot2grid (
(7, 1), (2, 0), rowspan = 2, colspan = 1)

axes1.plot(x, y)
axes2.plot(y, x)

# %% [markdown]
# - color: warna garis
# - linewidth: modifikasi width dari garis
# - marker: style untuk titik koordinat
# - markersize: mengatur ukuran marker
# - linestyle: style untuk line yang di plot

# %% [markdown]
# line plot : linestyle (https://matplotlib.org/stable/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D.set_linestyle)

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

plt.plot(x, y, color='green', linewidth=3, marker='*',
         markersize=15, linestyle='--')

plt.title("Chart Garis")

plt.ylabel('Sumbu Y')

plt.xlabel('Sumbu X')

plt.show()

# %% [markdown]
# # Thank You
